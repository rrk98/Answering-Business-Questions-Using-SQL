# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db

# %% [markdown]
# # Overview of the data

# %%
# %%sql
#
# SELECT
#     name,
#     type
# FROM sqlite_master
# WHERE type IN ("table","view");
# Out:
#  * sqlite:///chinook.db
# Done.
# [('album', 'table'),
#  ('artist', 'table'),
#  ('customer', 'table'),
#  ('employee', 'table'),
#  ('genre', 'table'),
#  ('invoice', 'table'),
#  ('invoice_line', 'table'),
#  ('media_type', 'table'),
#  ('playlist', 'table'),
#  ('playlist_track', 'table'),
#  ('track', 'table')]

# %% [markdown]
# # Selecting Albums to Purchase

# %% [markdown]
# The Chinook record store has just signed a deal with a new record label, and we've been tasked with selecting the first three albums that will be added to the store, from a list of four. All four albums are by artists that don't have any tracks in the store right now - we have the artist names, and the genre of music they produce:
#
# |      Artist Name     |  Genre  |
# |:--------------------:|:-------:|
# | Regal                | Hip-Hop |
# | Red Tone             | Punk    |
# | Meteor and the Girls | Pop     |
# | Slim Jim Bites       | Blues   |
#
# The record label specializes in artists from the USA, and they have given Chinook some money to advertise the new albums in the USA, so we're interested in finding out which genres sell the best in the USA and make a recommendation for the three artists whose albums we should purchase for the store.

# %%
# %%sql
#
# WITH us_customer AS (
#                      SELECT
#                          customer_id,
#                          country
#                      FROM customer
#                      WHERE country = 'USA'
#                     ),
#      us_purchases AS (
#                       SELECT
#                           i.invoice_id
#                       FROM invoice AS i
#                       INNER JOIN us_customer AS usc ON i.customer_id = usc.customer_id
#                      ),
#      us_detailed_purchases AS (
#                                SELECT
#                                    il.invoice_line_id,
#                                    il.invoice_id,
#                                    il.track_id,
#                                    il.quantity
#                                FROM us_purchases AS usp
#                                INNER JOIN invoice_line AS il ON usp.invoice_id = il.invoice_id
#                               ),
#      track_genre AS (
#                      SELECT
#                          t.track_id,
#                          g.name AS genre
#                      FROM track AS t
#                      INNER JOIN genre AS g ON t.genre_id = g.genre_id
#                     ),
#      genre_sales AS (
#                      SELECT
#                          tg.genre,
#                          SUM(quantity) AS number_of_tracks_sold
#                      FROM us_detailed_purchases AS usdp
#                      INNER JOIN track_genre AS tg ON usdp.track_id = tg.track_id
#                      GROUP BY tg.genre
#                      ORDER BY number_of_tracks_sold DESC
#                     ),
#      total_tracks_sold AS (
#                            SELECT SUM(number_of_tracks_sold) AS sum_total
#                            FROM genre_sales
#                           ),
#      genre_sales_overview AS (
#                               SELECT
#                                   genre,
#                                   number_of_tracks_sold AS 'Number of tracks sold',
#                                   CAST(number_of_tracks_sold AS FLOAT) / sum_total AS 'Number of tracks sold (in %)'
#                               FROM genre_sales, total_tracks_sold
#                              ),
#      considered_genres AS (
#                            SELECT *
#                            FROM genre_sales_overview
#                            WHERE genre LIKE "%Hip%"
#                            OR genre LIKE "%Punk%"
#                            OR genre LIKE "%Pop%"
#                            OR genre LIKE "%Blues%"
#                           )
# SELECT genre AS "Top 3 Genres"
# FROM considered_genres
# LIMIT 3;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Alternative & Punk',), ('Blues',), ('Pop',)]

# %% [markdown]
# * The top 3 genres by sales amongst the possible genres to be introduced are 'Punk', 'Blues', and 'Pop'.
# * Hence choose albums produced by the artists Red Tone, Slim Jim Bites, and Meteor and the Girls

# %% [markdown]
# # Analyzing Employee Sales Performance

# %% [markdown]
# * Each customer for the Chinook store gets assigned to a sales support agent within the company when they first make a purchase.
# * We have to analyze the purchases of customers belonging to each employee (i.e. we have to calculate the total dollar amount of sales assigned to each sales support agent within the company) to see if any sales support agent is performing either better or worse than the others.

# %%
# %%sql
#
# WITH customer_total_purchased AS (
#                                   SELECT
#                                       customer_id,
#                                       SUM(total) AS total_purchases
#                                   FROM invoice
#                                   GROUP BY customer_id
#                                  ),
#      sales_support_agent AS (
#                              SELECT *
#                              FROM employee
#                              WHERE title = 'Sales Support Agent'
#                             ),
#      sales_support_agent_customers AS (
#                                        SELECT
#                                            ssa.*,
#                                            c.customer_id
#                                        FROM sales_support_agent AS ssa
#                                        LEFT JOIN customer AS c ON ssa.employee_id = c.support_rep_id
#                                       ),
#      total_agent_sales AS (
#                            SELECT
#                                ssac.employee_id,
#                                ssac.first_name || ' ' || ssac.last_name AS name,
#                                ssac.hire_date,
#                                SUM(ctp.total_purchases) AS total_sales
#                            FROM sales_support_agent_customers AS ssac
#                            LEFT JOIN customer_total_purchased AS ctp ON ssac.customer_id = ctp.customer_id
#                            GROUP BY ssac.employee_id
#                           )
# SELECT *
# FROM total_agent_sales;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3, 'Jane Peacock', '2017-04-01 00:00:00', 1731.5099999999998),
#  (4, 'Margaret Park', '2017-05-03 00:00:00', 1584.0000000000002),
#  (5, 'Steve Johnson', '2017-10-17 00:00:00', 1393.92)]

# %% [markdown]
# * By looking only at the numbers, we might conclude that Jane performs better than Margaret, and Margaret performs better than Steve.
# * But by having a look at the hire date, we see that employees who joined earlier have cumulative sales amount more than that for those who joined later.

# %% [markdown]
# # Analyzing Sales by Country

# %%
# %%sql
#
# WITH invoice_customer AS (
#                           SELECT
#                               i.invoice_id,
#                               i.customer_id,
#                               i.total AS order_total,
#                               c.country AS customer_country
#                           FROM invoice AS i
#                           LEFT JOIN customer AS c ON i.customer_id = c.customer_id
#                          ),
#      country_mapping AS (
#                          SELECT
#                              ic.customer_country,
#                              CASE
#                                  WHEN COUNT(DISTINCT(ic.customer_id)) = 1 THEN "Other"
#                                  ELSE ic.customer_country
#                              END
#                              AS country_group
#                          FROM invoice_customer AS ic
#                          GROUP BY ic.customer_country
#                         ),
#      country_sales_analysis AS (
#                                 SELECT
#                                     cmap.country_group AS country_of_customer,
#                                     COUNT(DISTINCT(ic.customer_id)) AS total_number_of_customers,
#                                     SUM(ic.order_total) AS total_value_of_sales,
#                                     SUM(ic.order_total) / COUNT(DISTINCT(ic.customer_id)) AS average_value_of_sales_per_customer,
#                                     SUM(ic.order_total) / COUNT(ic.invoice_id) AS average_order_value,
#                                     CASE
#                                         WHEN cmap.country_group = 'Other' THEN 1
#                                         ELSE 0
#                                     END
#                                     AS sorting_code
#                                 FROM invoice_customer AS ic
#                                 INNER JOIN country_mapping AS cmap ON ic.customer_country = cmap.customer_country
#                                 GROUP BY cmap.country_group
#                                 ORDER BY total_value_of_sales DESC
#                                ),
#      formatted_country_sales_analysis AS (
#                                           SELECT
#                                               csa.country_of_customer,
#                                               csa.total_number_of_customers,
#                                               csa.total_value_of_sales,
#                                               csa.average_value_of_sales_per_customer,
#                                               csa.average_order_value
#                                           FROM country_sales_analysis AS csa
#                                           ORDER BY csa.sorting_code
#                                          )
# SELECT *
# FROM formatted_country_sales_analysis;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('USA', 13, 1040.4899999999998, 80.0376923076923, 7.942671755725189),
#  ('Canada', 8, 535.5900000000001, 66.94875000000002, 7.047236842105265),
#  ('Brazil', 5, 427.68000000000006, 85.53600000000002, 7.0111475409836075),
#  ('France', 5, 389.0699999999999, 77.81399999999998, 7.781399999999998),
#  ('Germany', 4, 334.62, 83.655, 8.161463414634147),
#  ('Czech Republic', 2, 273.24000000000007, 136.62000000000003, 9.108000000000002),
#  ('United Kingdom', 3, 245.52, 81.84, 8.768571428571429),
#  ('Portugal', 2, 185.13000000000002, 92.56500000000001, 6.383793103448276),
#  ('India', 2, 183.14999999999998, 91.57499999999999, 8.72142857142857),
#  ('Other', 15, 1094.9400000000003, 72.99600000000002, 7.44857142857143)]

# %% [markdown]
# # Albums vs Individual Tracks

# %% [markdown]
# The Chinook store is setup in a way that allows customer to make purchases in one of the two ways:
#
# 1. purchase a whole album
# 2. purchase a collection of one or more individual tracks.
#
# The store does not let customers purchase a whole album, and then add individual tracks to that same purchase (unless they do that by choosing each track manually). When customers purchase albums they are charged the same price as if they had purchased each of those tracks separately.
#
# Management are currently considering changing their purchasing strategy to save money. The strategy they are considering is to purchase only the most popular tracks from each album from record companies, instead of purchasing every track from an album.
#
# We have been asked to find out what percentage of purchases are individual tracks vs whole albums, so that management can use this data to understand the effect this decision might have on overall revenue.
#
# We have two edge cases to consider:
#
# 1. Albums that have only one or two tracks are likely to be purchased by customers as part of a collection of individual tracks.
# 2. Customers may decide to manually select every track from an album, and then add a few individual tracks from other albums to their purchase.
#
# In the first case, since our analysis is concerned with maximizing revenue we can safely ignore albums consisting of only a few tracks. The company has previously done analysis to confirm that the second case does not happen often, so we can ignore this case also.

# %%
# %%sql
#
# WITH invoices_overview AS (
#                            SELECT
#                                il.invoice_id,
#                                il.track_id
#                            FROM invoice_line AS il
#                           ),
#      tracks_overview AS (
#                          SELECT
#                              t.track_id,
#                              t.name AS track_name,
#                              t.album_id
#                          FROM track AS t
#                         ),
#      invoice_details AS (
#                          SELECT
#                              iv.invoice_id,
#                              iv.track_id,
#                              tk.track_name,
#                              tk.album_id
#                          FROM invoices_overview AS iv
#                          INNER JOIN tracks_overview AS tk ON iv.track_id = tk.track_id
#                         ),
#      purchase_type_mapper AS (
#                               SELECT
#                                   ivdet.invoice_id,
#                                   CASE
#                                       WHEN
#                                           (
#                                            SELECT iv.track_id
#                                            FROM invoices_overview AS iv
#                                            WHERE iv.invoice_id = ivdet.invoice_id
#
#                                            EXCEPT
#
#                                            SELECT tk.track_id
#                                            FROM tracks_overview AS tk
#                                            WHERE tk.album_id = ivdet.album_id
#                                           ) IS NULL
#
#                                           AND
#
#                                           (
#                                            SELECT tk.track_id
#                                            FROM tracks_overview AS tk
#                                            WHERE tk.album_id = ivdet.album_id
#
#                                            EXCEPT
#
#                                            SELECT iv.track_id
#                                            FROM invoices_overview AS iv
#                                            WHERE iv.invoice_id = ivdet.invoice_id
#                                           ) IS NULL
#                                       THEN "album"
#                                       ELSE "collection"
#                                   END
#                                   AS purchasing_strategy
#                               FROM invoice_details AS ivdet
#                               GROUP BY ivdet.invoice_id
#                              ),
#      edge_case_mapper AS (
#                           SELECT
#                               ivdet.invoice_id,
#                               ptmap.purchasing_strategy,
#                               CASE
#                                   WHEN
#                                       ptmap.purchasing_strategy = 'album'
#                                       AND
#                                       COUNT(ivdet.track_id) < 3
#                                   THEN "yes"
#                                   WHEN
#                                       ptmap.purchasing_strategy = 'album'
#                                       AND
#                                       COUNT(ivdet.track_id) >= 3
#                                   THEN "no"
#                                   WHEN
#                                       ptmap.purchasing_strategy = 'collection'
#                                       AND
#                                       (
#                                           SELECT
#                                               idet.album_id || COUNT(idet.track_id)
#                                           FROM invoice_details AS idet
#                                           WHERE idet.invoice_id = ivdet.invoice_id
#                                           GROUP BY idet.album_id
#
#                                           INTERSECT
#
#                                           SELECT
#                                               tk.album_id || COUNT(tk.track_id)
#                                           FROM tracks_overview AS tk
#                                           WHERE tk.album_id IN (
#                                                                 SELECT DISTINCT(idet.album_id)
#                                                                 FROM invoice_details AS idet
#                                                                 WHERE idet.invoice_id = ivdet.invoice_id
#                                                                )
#                                           GROUP BY tk.album_id
#                                       ) IS NOT NULL
#                                   THEN "yes"
#                                   ELSE "no"
#                               END
#                               AS edge_case
#                           FROM invoice_details AS ivdet
#                           INNER JOIN purchase_type_mapper AS ptmap ON ivdet.invoice_id = ptmap.invoice_id
#                           GROUP BY ivdet.invoice_id
#                          )
# SELECT
#     edgemap.purchasing_strategy AS "Purchasing Strategy",
#     COUNT(i.invoice_id) AS "Number of Invoices",
#     COUNT(i.invoice_id) / CAST((SELECT COUNT(invoice_id) FROM invoice) AS FLOAT) AS "Percentage of Invoices"
# FROM invoice AS i
# INNER JOIN edge_case_mapper AS edgemap ON i.invoice_id = edgemap.invoice_id
# GROUP BY edgemap.purchasing_strategy;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('album', 114, 0.18566775244299674), ('collection', 500, 0.8143322475570033)]

# %% [markdown]
# * The Chinook store should not continue to buy full albums from record companies.

# %% [markdown]
# # Artist who is used in the most playlists

# %%
# %%sql
#
# WITH track_artist_overview AS (
#                                SELECT
#                                    t.track_id,
#                                    al.artist_id
#                                FROM track AS t
#                                INNER JOIN album AS al ON t.album_id = al.album_id
#                               ),
#      artist_playlist_occurances AS (
#                                     SELECT
#                                         tao.artist_id,
#                                         COUNT(DISTINCT(pt.playlist_id)) AS number_of_playlists_occured_in
#                                     FROM playlist_track AS pt
#                                     INNER JOIN track_artist_overview AS tao ON pt.track_id = tao.track_id
#                                     GROUP BY tao.artist_id
#                                     ORDER BY number_of_playlists_occured_in DESC
#                                    )
# SELECT
#     a.name AS artist_name,
#     apo.number_of_playlists_occured_in
# FROM artist_playlist_occurances AS apo
# INNER JOIN artist AS a ON apo.artist_id = a.artist_id
# ;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Eugene Ormandy', 7),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 6),
#  ("The King's Singers", 6),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 6),
#  ('English Concert & Trevor Pinnock', 6),
#  ('Philip Glass Ensemble', 5),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 5),
#  ('Martin Roscoe', 5),
#  ('Julian Bream', 5),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 5),
#  ('Adrian Leaper & Doreen de Feis', 5),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 5),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 5),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 5),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 5),
#  ('Michael Tilson Thomas & San Francisco Symphony', 5),
#  ('Antal Doráti & London Symphony Orchestra', 5),
#  ('Gustav Mahler', 5),
#  ('Maurizio Pollini', 5),
#  ('Berliner Philharmoniker & Hans Rosbaud', 5),
#  ('James Levine', 5),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 5),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 5),
#  ('Ton Koopman', 5),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 5),
#  ('Luciano Pavarotti', 5),
#  ('Barry Wordsworth & BBC Concert Orchestra', 5),
#  ('Sir Georg Solti & Wiener Philharmoniker', 5),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 5),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 5),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 5),
#  ('Scholars Baroque Ensemble', 5),
#  ('Yo-Yo Ma', 5),
#  ('Wilhelm Kempff', 5),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 5),
#  ('Alberto Turco & Nova Schola Gregoriana', 5),
#  ('Nash Ensemble', 4),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 4),
#  ('Emerson String Quartet', 4),
#  ('Gerald Moore', 4),
#  ('Michele Campanella', 4),
#  ('Itzhak Perlman', 4),
#  ('Göteborgs Symfoniker & Neeme Järvi', 4),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 4),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 4),
#  ('Roger Norrington, London Classical Players', 4),
#  ('The 12 Cellists of The Berlin Philharmonic', 4),
#  ('Les Arts Florissants & William Christie', 4),
#  ('Yehudi Menuhin', 4),
#  ('Otto Klemperer & Philharmonia Orchestra', 4),
#  ('Fretwork', 4),
#  ("Christopher O'Riley", 4),
#  ('Choir Of Westminster Abbey & Simon Preston', 4),
#  ('Edo de Waart & San Francisco Symphony', 4),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 4),
#  ('Orchestra of The Age of Enlightenment', 4),
#  ('Sergei Prokofiev & Yuri Temirkanov', 4),
#  ('Aaron Copland & London Symphony Orchestra', 4),
#  ('Leonard Bernstein & New York Philharmonic', 4),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 4),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 4),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 4),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 4),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 4),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 4),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 4),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 4),
#  ('Temple of the Dog', 4),
#  ('Stone Temple Pilots', 4),
#  ('Soundgarden', 4),
#  ('Pearl Jam', 4),
#  ('Ozzy Osbourne', 4),
#  ('Nirvana', 4),
#  ('Mötley Crüe', 4),
#  ('Iron Maiden', 4),
#  ('Eric Clapton', 4),
#  ('Djavan', 4),
#  ('Gonzaguinha', 4),
#  ('Metallica', 4),
#  ('Gilberto Gil', 4),
#  ('Chico Buarque', 4),
#  ('Caetano Veloso', 4),
#  ('Alice In Chains', 4),
#  ('Accept', 4),
#  ('Nicolaus Esterhazy Sinfonia', 3),
#  ('Habib Koité and Bamada', 3),
#  ('House Of Pain', 3),
#  ('Scorpions', 3),
#  ('Dread Zeppelin', 3),
#  ('Zeca Pagodinho', 3),
#  ('Van Halen', 3),
#  ('UB40', 3),
#  ('U2', 3),
#  ('Titãs', 3),
#  ('Tim Maia', 3),
#  ('The Tea Party', 3),
#  ('The Rolling Stones', 3),
#  ('The Police', 3),
#  ('The Cult', 3),
#  ('The Clash', 3),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 3),
#  ('Smashing Pumpkins', 3),
#  ('Skank', 3),
#  ('Rush', 3),
#  ('Red Hot Chili Peppers', 3),
#  ('Raimundos', 3),
#  ('R.E.M.', 3),
#  ('R.E.M. Feat. Kate Pearson', 3),
#  ('Planet Hemp', 3),
#  ('Passengers', 3),
#  ('Page & Plant', 3),
#  ('Os Paralamas Do Sucesso', 3),
#  ('Motörhead', 3),
#  ('Lenny Kravitz', 3),
#  ('Legião Urbana', 3),
#  ('Judas Priest', 3),
#  ('Jota Quest', 3),
#  ('Joe Satriani', 3),
#  ('Jamiroquai', 3),
#  ('James Brown', 3),
#  ('Incognito', 3),
#  ("Guns N' Roses", 3),
#  ('Funk Como Le Gusta', 3),
#  ('Foo Fighters', 3),
#  ('Falamansa', 3),
#  ('Faith No More', 3),
#  ('Def Leppard', 3),
#  ('Cássia Eller', 3),
#  ('Miles Davis', 3),
#  ('Santana', 3),
#  ('Deep Purple', 3),
#  ('Green Day', 3),
#  ('Spyro Gyra', 3),
#  ('Kiss', 3),
#  ('Queen', 3),
#  ('Jorge Ben', 3),
#  ('Milton Nascimento', 3),
#  ('Elis Regina', 3),
#  ('Ed Motta', 3),
#  ('Led Zeppelin', 3),
#  ('Cidade Negra', 3),
#  ('Chico Science & Nação Zumbi', 3),
#  ('Bruce Dickinson', 3),
#  ('Body Count', 3),
#  ('Black Sabbath', 3),
#  ('BackBeat', 3),
#  ('Audioslave', 3),
#  ('Apocalyptica', 3),
#  ('Antônio Carlos Jobim', 3),
#  ('Alanis Morissette', 3),
#  ('Aerosmith', 3),
#  ('AC/DC', 3),
#  ('Calexico', 2),
#  ('Amy Winehouse', 2),
#  ('Chris Cornell', 2),
#  ('Aaron Goldberg', 2),
#  ('Luciana Souza/Romero Lubambo', 2),
#  ('The Posies', 2),
#  ('Karsh Kale', 2),
#  ('Aisha Duo', 2),
#  ('Cake', 2),
#  ('Aquaman', 2),
#  ('Battlestar Galactica (Classic)', 2),
#  ('The Office', 2),
#  ('Velvet Revolver', 2),
#  ('Lost', 2),
#  ('Heroes', 2),
#  ('Battlestar Galactica', 2),
#  ('The Who', 2),
#  ('The Doors', 2),
#  ('The Black Crowes', 2),
#  ('System Of A Down', 2),
#  ('Stevie Ray Vaughan & Double Trouble', 2),
#  ('Raul Seixas', 2),
#  ('Pink Floyd', 2),
#  ("Paul D'Ianno", 2),
#  ('Olodum', 2),
#  ('O Terço', 2),
#  ('Mônica Marianno', 2),
#  ('Men At Work', 2),
#  ('Marvin Gaye', 2),
#  ('Marisa Monte', 2),
#  ('Marillion', 2),
#  ('Lulu Santos', 2),
#  ('João Suplicy', 2),
#  ('Jimi Hendrix', 2),
#  ('JET', 2),
#  ('Godsmack', 2),
#  ('Frank Sinatra', 2),
#  ('Dennis Chambers', 2),
#  ('Creedence Clearwater Revival', 2),
#  ('Vinícius De Moraes', 2),
#  ('Toquinho & Vinícius', 2),
#  ('Gene Krupa', 2),
#  ('Os Mutantes', 2),
#  ('David Coverdale', 2),
#  ('O Rappa', 2),
#  ('Marcos Valle', 2),
#  ('Frank Zappa & Captain Beefheart', 2),
#  ('Various Artists', 2),
#  ('Cláudio Zoli', 2),
#  ('Buddy Guy', 2),
#  ('Black Label Society', 2),
#  ('Billy Cobham', 2)]

# %% [markdown]
# * The artist Eugene Ormandy, appeared in the most playlists (7 times).

# %% [markdown]
# # Tracks that have been purchased vs not purchased

# %%
# %%sql
#
# SELECT
#     COUNT(DISTINCT(track.track_id)) AS 'Tracks Available',
#     COUNT(DISTINCT(invoice_line.track_id)) AS 'Tracks Purchased',
#     COUNT(DISTINCT(track.track_id)) - COUNT(DISTINCT(invoice_line.track_id)) AS 'Tracks not Purchased'
# FROM track,invoice_line;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3503, 1806, 1697)]

# %% [markdown]
# # Q : Is the range of tracks in the store reflective of their sales popularity?

# %%
# %%sql
#
# SELECT COUNT(*) AS 'Number Of Tracks in Store'
# FROM track
# ;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3503,)]

# %%
# %%sql
#
# WITH store_tracks AS (
#                       SELECT track_id
#                       FROM track AS t
#                      ),
#      invoice_tracks AS (
#                         SELECT
#                             track_id,
#                             quantity AS track_quantity
#                         FROM invoice_line AS il
#                        )
# SELECT
#     st.track_id,
#     COUNT(it.track_quantity) AS Number_Of_Track_Purchases
# FROM store_tracks AS st
# LEFT JOIN invoice_tracks AS it ON st.track_id = it.track_id
# GROUP BY st.track_id;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 8),
#  (2, 3),
#  (3, 1),
#  (4, 4),
#  (5, 1),
#  (6, 13),
#  (7, 4),
#  (8, 6),
#  (9, 9),
#  (10, 6),
#  (11, 5),
#  (12, 7),
#  (13, 10),
#  (14, 6),
#  (15, 4),
#  (16, 8),
#  (17, 5),
#  (18, 7),
#  (19, 6),
#  (20, 7),
#  (21, 7),
#  (22, 6),
#  (23, 6),
#  (24, 6),
#  (25, 2),
#  (26, 6),
#  (27, 6),
#  (28, 4),
#  (29, 5),
#  (30, 6),
#  (31, 4),
#  (32, 8),
#  (33, 7),
#  (34, 4),
#  (35, 6),
#  (36, 7),
#  (37, 3),
#  (38, 6),
#  (39, 7),
#  (40, 6),
#  (41, 4),
#  (42, 6),
#  (43, 6),
#  (44, 6),
#  (45, 5),
#  (46, 9),
#  (47, 5),
#  (48, 5),
#  (49, 6),
#  (50, 4),
#  (51, 5),
#  (52, 4),
#  (53, 4),
#  (54, 6),
#  (55, 4),
#  (56, 3),
#  (57, 4),
#  (58, 8),
#  (59, 3),
#  (60, 6),
#  (61, 7),
#  (62, 5),
#  (63, 1),
#  (64, 1),
#  (65, 1),
#  (66, 3),
#  (67, 1),
#  (68, 1),
#  (69, 1),
#  (70, 1),
#  (71, 1),
#  (72, 1),
#  (73, 2),
#  (74, 1),
#  (75, 1),
#  (76, 2),
#  (77, 5),
#  (78, 3),
#  (79, 4),
#  (80, 7),
#  (81, 5),
#  (82, 5),
#  (83, 5),
#  (84, 3),
#  (85, 4),
#  (86, 2),
#  (87, 1),
#  (88, 2),
#  (89, 2),
#  (90, 1),
#  (91, 2),
#  (92, 2),
#  (93, 5),
#  (94, 6),
#  (95, 2),
#  (96, 1),
#  (97, 2),
#  (98, 1),
#  (99, 0),
#  (100, 1),
#  (101, 0),
#  (102, 3),
#  (103, 1),
#  (104, 0),
#  (105, 1),
#  (106, 0),
#  (107, 0),
#  (108, 1),
#  (109, 1),
#  (110, 2),
#  (111, 0),
#  (112, 0),
#  (113, 0),
#  (114, 0),
#  (115, 0),
#  (116, 0),
#  (117, 0),
#  (118, 0),
#  (119, 0),
#  (120, 0),
#  (121, 0),
#  (122, 0),
#  (123, 0),
#  (124, 0),
#  (125, 0),
#  (126, 1),
#  (127, 0),
#  (128, 1),
#  (129, 0),
#  (130, 2),
#  (131, 1),
#  (132, 1),
#  (133, 0),
#  (134, 2),
#  (135, 1),
#  (136, 0),
#  (137, 1),
#  (138, 1),
#  (139, 2),
#  (140, 1),
#  (141, 0),
#  (142, 1),
#  (143, 0),
#  (144, 0),
#  (145, 0),
#  (146, 2),
#  (147, 2),
#  (148, 0),
#  (149, 2),
#  (150, 4),
#  (151, 9),
#  (152, 5),
#  (153, 8),
#  (154, 7),
#  (155, 4),
#  (156, 1),
#  (157, 4),
#  (158, 7),
#  (159, 0),
#  (160, 3),
#  (161, 2),
#  (162, 3),
#  (163, 3),
#  (164, 3),
#  (165, 3),
#  (166, 0),
#  (167, 0),
#  (168, 0),
#  (169, 0),
#  (170, 0),
#  (171, 0),
#  (172, 2),
#  (173, 0),
#  (174, 0),
#  (175, 0),
#  (176, 0),
#  (177, 0),
#  (178, 0),
#  (179, 0),
#  (180, 0),
#  (181, 0),
#  (182, 0),
#  (183, 1),
#  (184, 1),
#  (185, 0),
#  (186, 1),
#  (187, 0),
#  (188, 1),
#  (189, 0),
#  (190, 0),
#  (191, 0),
#  (192, 0),
#  (193, 0),
#  (194, 1),
#  (195, 3),
#  (196, 2),
#  (197, 2),
#  (198, 3),
#  (199, 2),
#  (200, 1),
#  (201, 3),
#  (202, 2),
#  (203, 1),
#  (204, 3),
#  (205, 0),
#  (206, 1),
#  (207, 3),
#  (208, 1),
#  (209, 0),
#  (210, 0),
#  (211, 0),
#  (212, 1),
#  (213, 0),
#  (214, 0),
#  (215, 0),
#  (216, 0),
#  (217, 0),
#  (218, 0),
#  (219, 1),
#  (220, 0),
#  (221, 0),
#  (222, 1),
#  (223, 0),
#  (224, 1),
#  (225, 1),
#  (226, 2),
#  (227, 1),
#  (228, 1),
#  (229, 1),
#  (230, 0),
#  (231, 0),
#  (232, 0),
#  (233, 1),
#  (234, 0),
#  (235, 0),
#  (236, 0),
#  (237, 1),
#  (238, 0),
#  (239, 0),
#  (240, 0),
#  (241, 0),
#  (242, 0),
#  (243, 0),
#  (244, 0),
#  (245, 0),
#  (246, 0),
#  (247, 0),
#  (248, 0),
#  (249, 0),
#  (250, 0),
#  (251, 0),
#  (252, 0),
#  (253, 0),
#  (254, 0),
#  (255, 0),
#  (256, 0),
#  (257, 0),
#  (258, 0),
#  (259, 0),
#  (260, 0),
#  (261, 1),
#  (262, 0),
#  (263, 0),
#  (264, 0),
#  (265, 0),
#  (266, 0),
#  (267, 0),
#  (268, 1),
#  (269, 0),
#  (270, 0),
#  (271, 0),
#  (272, 0),
#  (273, 0),
#  (274, 0),
#  (275, 0),
#  (276, 0),
#  (277, 0),
#  (278, 0),
#  (279, 0),
#  (280, 0),
#  (281, 0),
#  (282, 0),
#  (283, 0),
#  (284, 0),
#  (285, 0),
#  (286, 0),
#  (287, 0),
#  (288, 0),
#  (289, 0),
#  (290, 0),
#  (291, 0),
#  (292, 0),
#  (293, 0),
#  (294, 0),
#  (295, 0),
#  (296, 0),
#  (297, 0),
#  (298, 1),
#  (299, 0),
#  (300, 0),
#  (301, 1),
#  (302, 0),
#  (303, 0),
#  (304, 0),
#  (305, 0),
#  (306, 0),
#  (307, 0),
#  (308, 0),
#  (309, 0),
#  (310, 0),
#  (311, 0),
#  (312, 0),
#  (313, 0),
#  (314, 0),
#  (315, 0),
#  (316, 0),
#  (317, 0),
#  (318, 0),
#  (319, 0),
#  (320, 0),
#  (321, 0),
#  (322, 0),
#  (323, 0),
#  (324, 0),
#  (325, 0),
#  (326, 0),
#  (327, 0),
#  (328, 0),
#  (329, 0),
#  (330, 0),
#  (331, 0),
#  (332, 0),
#  (333, 0),
#  (334, 0),
#  (335, 0),
#  (336, 0),
#  (337, 2),
#  (338, 0),
#  (339, 0),
#  (340, 1),
#  (341, 1),
#  (342, 1),
#  (343, 0),
#  (344, 1),
#  (345, 0),
#  (346, 1),
#  (347, 0),
#  (348, 1),
#  (349, 1),
#  (350, 1),
#  (351, 0),
#  (352, 0),
#  (353, 0),
#  (354, 0),
#  (355, 0),
#  (356, 0),
#  (357, 0),
#  (358, 0),
#  (359, 0),
#  (360, 0),
#  (361, 0),
#  (362, 0),
#  (363, 0),
#  (364, 0),
#  (365, 0),
#  (366, 0),
#  (367, 0),
#  (368, 0),
#  (369, 0),
#  (370, 0),
#  (371, 0),
#  (372, 0),
#  (373, 0),
#  (374, 0),
#  (375, 0),
#  (376, 0),
#  (377, 0),
#  (378, 0),
#  (379, 0),
#  (380, 0),
#  (381, 0),
#  (382, 0),
#  (383, 1),
#  (384, 0),
#  (385, 0),
#  (386, 0),
#  (387, 0),
#  (388, 0),
#  (389, 0),
#  (390, 0),
#  (391, 0),
#  (392, 1),
#  (393, 0),
#  (394, 0),
#  (395, 0),
#  (396, 0),
#  (397, 0),
#  (398, 0),
#  (399, 0),
#  (400, 0),
#  (401, 0),
#  (402, 1),
#  (403, 0),
#  (404, 0),
#  (405, 0),
#  (406, 0),
#  (407, 0),
#  (408, 0),
#  (409, 1),
#  (410, 1),
#  (411, 2),
#  (412, 0),
#  (413, 1),
#  (414, 0),
#  (415, 2),
#  (416, 0),
#  (417, 0),
#  (418, 0),
#  (419, 4),
#  (420, 1),
#  (421, 6),
#  (422, 4),
#  (423, 3),
#  (424, 2),
#  (425, 2),
#  (426, 5),
#  (427, 4),
#  (428, 3),
#  (429, 1),
#  (430, 2),
#  (431, 2),
#  (432, 2),
#  (433, 3),
#  (434, 2),
#  (435, 2),
#  (436, 2),
#  (437, 2),
#  (438, 2),
#  (439, 2),
#  (440, 1),
#  (441, 2),
#  (442, 2),
#  (443, 1),
#  (444, 4),
#  (445, 2),
#  (446, 2),
#  (447, 1),
#  (448, 1),
#  (449, 4),
#  (450, 1),
#  (451, 1),
#  (452, 2),
#  (453, 2),
#  (454, 2),
#  (455, 1),
#  (456, 0),
#  (457, 0),
#  (458, 0),
#  (459, 3),
#  (460, 0),
#  (461, 1),
#  (462, 0),
#  (463, 0),
#  (464, 0),
#  (465, 1),
#  (466, 0),
#  (467, 0),
#  (468, 2),
#  (469, 3),
#  (470, 3),
#  (471, 0),
#  (472, 2),
#  (473, 1),
#  (474, 2),
#  (475, 3),
#  (476, 2),
#  (477, 2),
#  (478, 1),
#  (479, 5),
#  (480, 1),
#  (481, 7),
#  (482, 3),
#  (483, 1),
#  (484, 1),
#  (485, 2),
#  (486, 3),
#  (487, 1),
#  (488, 2),
#  (489, 0),
#  (490, 0),
#  (491, 0),
#  (492, 1),
#  (493, 0),
#  (494, 0),
#  (495, 0),
#  (496, 1),
#  (497, 0),
#  (498, 0),
#  (499, 0),
#  (500, 0),
#  (501, 0),
#  (502, 0),
#  (503, 0),
#  (504, 0),
#  (505, 0),
#  (506, 0),
#  (507, 0),
#  (508, 0),
#  (509, 0),
#  (510, 1),
#  (511, 0),
#  (512, 0),
#  (513, 0),
#  (514, 1),
#  (515, 0),
#  (516, 0),
#  (517, 1),
#  (518, 0),
#  (519, 0),
#  (520, 0),
#  (521, 0),
#  (522, 0),
#  (523, 0),
#  (524, 1),
#  (525, 0),
#  (526, 0),
#  (527, 0),
#  (528, 1),
#  (529, 5),
#  (530, 2),
#  (531, 2),
#  (532, 2),
#  (533, 1),
#  (534, 1),
#  (535, 2),
#  (536, 2),
#  (537, 1),
#  (538, 1),
#  (539, 2),
#  (540, 2),
#  (541, 2),
#  (542, 2),
#  (543, 0),
#  (544, 1),
#  (545, 1),
#  (546, 1),
#  (547, 0),
#  (548, 3),
#  (549, 0),
#  (550, 0),
#  (551, 0),
#  (552, 0),
#  (553, 1),
#  (554, 0),
#  (555, 0),
#  (556, 0),
#  (557, 0),
#  (558, 0),
#  (559, 0),
#  (560, 0),
#  (561, 0),
#  (562, 0),
#  (563, 0),
#  (564, 0),
#  (565, 0),
#  (566, 0),
#  (567, 0),
#  (568, 0),
#  (569, 0),
#  (570, 0),
#  (571, 2),
#  (572, 3),
#  (573, 1),
#  (574, 1),
#  (575, 0),
#  (576, 0),
#  (577, 1),
#  (578, 0),
#  (579, 1),
#  (580, 2),
#  (581, 0),
#  (582, 0),
#  (583, 0),
#  (584, 0),
#  (585, 1),
#  (586, 0),
#  (587, 1),
#  (588, 0),
#  (589, 0),
#  (590, 0),
#  (591, 0),
#  (592, 2),
#  (593, 1),
#  (594, 1),
#  (595, 0),
#  (596, 0),
#  (597, 2),
#  (598, 0),
#  (599, 1),
#  (600, 1),
#  (601, 0),
#  (602, 1),
#  (603, 0),
#  (604, 1),
#  (605, 2),
#  (606, 0),
#  (607, 0),
#  (608, 2),
#  (609, 1),
#  (610, 3),
#  (611, 1),
#  (612, 1),
#  (613, 0),
#  (614, 1),
#  (615, 3),
#  (616, 0),
#  (617, 0),
#  (618, 0),
#  (619, 1),
#  (620, 1),
#  (621, 0),
#  (622, 1),
#  (623, 0),
#  (624, 0),
#  (625, 0),
#  (626, 0),
#  (627, 0),
#  (628, 0),
#  (629, 0),
#  (630, 0),
#  (631, 0),
#  (632, 0),
#  (633, 0),
#  (634, 0),
#  (635, 0),
#  (636, 0),
#  (637, 0),
#  (638, 0),
#  (639, 0),
#  (640, 0),
#  (641, 0),
#  (642, 0),
#  (643, 0),
#  (644, 0),
#  (645, 0),
#  (646, 0),
#  (647, 0),
#  (648, 0),
#  (649, 0),
#  (650, 0),
#  (651, 0),
#  (652, 0),
#  (653, 0),
#  (654, 0),
#  (655, 0),
#  (656, 0),
#  (657, 0),
#  (658, 0),
#  (659, 0),
#  (660, 0),
#  (661, 0),
#  (662, 0),
#  (663, 0),
#  (664, 0),
#  (665, 0),
#  (666, 0),
#  (667, 0),
#  (668, 0),
#  (669, 0),
#  (670, 0),
#  (671, 0),
#  (672, 0),
#  (673, 0),
#  (674, 0),
#  (675, 1),
#  (676, 1),
#  (677, 0),
#  (678, 0),
#  (679, 0),
#  (680, 0),
#  (681, 2),
#  (682, 1),
#  (683, 0),
#  (684, 1),
#  (685, 0),
#  (686, 1),
#  (687, 1),
#  (688, 1),
#  (689, 1),
#  (690, 2),
#  (691, 1),
#  (692, 2),
#  (693, 1),
#  (694, 0),
#  (695, 2),
#  (696, 2),
#  (697, 5),
#  (698, 2),
#  (699, 3),
#  (700, 2),
#  (701, 2),
#  (702, 1),
#  (703, 1),
#  (704, 1),
#  (705, 2),
#  (706, 2),
#  (707, 2),
#  (708, 1),
#  (709, 2),
#  (710, 1),
#  (711, 4),
#  (712, 2),
#  (713, 1),
#  (714, 1),
#  (715, 0),
#  (716, 0),
#  (717, 0),
#  (718, 0),
#  (719, 1),
#  (720, 0),
#  (721, 0),
#  (722, 0),
#  (723, 0),
#  (724, 0),
#  (725, 0),
#  (726, 0),
#  (727, 0),
#  (728, 0),
#  (729, 0),
#  (730, 0),
#  (731, 0),
#  (732, 0),
#  (733, 0),
#  (734, 0),
#  (735, 0),
#  (736, 0),
#  (737, 0),
#  (738, 0),
#  (739, 1),
#  (740, 1),
#  (741, 0),
#  (742, 0),
#  (743, 0),
#  (744, 0),
#  (745, 0),
#  (746, 0),
#  (747, 0),
#  (748, 1),
#  (749, 1),
#  (750, 1),
#  (751, 2),
#  (752, 0),
#  (753, 0),
#  (754, 0),
#  (755, 1),
#  (756, 0),
#  (757, 1),
#  (758, 0),
#  (759, 0),
#  (760, 0),
#  (761, 0),
#  (762, 0),
#  (763, 0),
#  (764, 0),
#  (765, 0),
#  (766, 0),
#  (767, 0),
#  (768, 1),
#  (769, 0),
#  (770, 0),
#  (771, 1),
#  (772, 0),
#  (773, 2),
#  (774, 0),
#  (775, 0),
#  (776, 0),
#  (777, 0),
#  (778, 3),
#  (779, 0),
#  (780, 0),
#  (781, 2),
#  (782, 0),
#  (783, 0),
#  (784, 1),
#  (785, 0),
#  (786, 0),
#  (787, 1),
#  (788, 1),
#  (789, 0),
#  (790, 0),
#  (791, 0),
#  (792, 0),
#  (793, 0),
#  (794, 1),
#  (795, 1),
#  (796, 0),
#  (797, 0),
#  (798, 0),
#  (799, 0),
#  (800, 1),
#  (801, 0),
#  (802, 2),
#  (803, 1),
#  (804, 1),
#  (805, 0),
#  (806, 0),
#  (807, 2),
#  (808, 1),
#  (809, 1),
#  (810, 2),
#  (811, 1),
#  (812, 1),
#  (813, 1),
#  (814, 2),
#  (815, 1),
#  (816, 0),
#  (817, 0),
#  (818, 1),
#  (819, 2),
#  (820, 0),
#  (821, 0),
#  (822, 2),
#  (823, 0),
#  (824, 0),
#  (825, 0),
#  (826, 2),
#  (827, 1),
#  (828, 1),
#  (829, 2),
#  (830, 1),
#  (831, 2),
#  (832, 2),
#  (833, 2),
#  (834, 3),
#  (835, 0),
#  (836, 4),
#  (837, 2),
#  (838, 0),
#  (839, 3),
#  (840, 1),
#  (841, 2),
#  (842, 0),
#  (843, 0),
#  (844, 0),
#  (845, 0),
#  (846, 0),
#  (847, 0),
#  (848, 0),
#  (849, 0),
#  (850, 0),
#  (851, 1),
#  (852, 0),
#  (853, 0),
#  (854, 0),
#  (855, 0),
#  (856, 0),
#  (857, 1),
#  (858, 0),
#  (859, 0),
#  (860, 0),
#  (861, 1),
#  (862, 0),
#  (863, 0),
#  (864, 0),
#  (865, 0),
#  (866, 0),
#  (867, 0),
#  (868, 0),
#  (869, 0),
#  (870, 0),
#  (871, 0),
#  (872, 0),
#  (873, 0),
#  (874, 0),
#  (875, 1),
#  (876, 0),
#  (877, 0),
#  (878, 0),
#  (879, 0),
#  (880, 0),
#  (881, 0),
#  (882, 0),
#  (883, 0),
#  (884, 0),
#  (885, 0),
#  (886, 0),
#  (887, 0),
#  (888, 0),
#  (889, 0),
#  (890, 0),
#  (891, 2),
#  (892, 3),
#  (893, 2),
#  (894, 5),
#  (895, 3),
#  (896, 3),
#  (897, 5),
#  (898, 4),
#  (899, 3),
#  (900, 4),
#  (901, 4),
#  (902, 3),
#  (903, 2),
#  (904, 4),
#  (905, 4),
#  (906, 3),
#  (907, 2),
#  (908, 4),
#  (909, 0),
#  (910, 1),
#  (911, 1),
#  (912, 0),
#  (913, 2),
#  (914, 1),
#  (915, 2),
#  (916, 1),
#  (917, 3),
#  (918, 2),
#  (919, 1),
#  (920, 3),
#  (921, 2),
#  (922, 2),
#  (923, 1),
#  (924, 0),
#  (925, 1),
#  (926, 0),
#  (927, 0),
#  (928, 1),
#  (929, 0),
#  (930, 0),
#  (931, 1),
#  (932, 1),
#  (933, 1),
#  (934, 0),
#  (935, 0),
#  (936, 0),
#  (937, 3),
#  (938, 0),
#  (939, 0),
#  (940, 1),
#  (941, 0),
#  (942, 0),
#  (943, 1),
#  (944, 2),
#  (945, 0),
#  (946, 0),
#  (947, 0),
#  (948, 1),
#  (949, 0),
#  (950, 1),
#  (951, 0),
#  (952, 1),
#  (953, 0),
#  (954, 0),
#  (955, 1),
#  (956, 0),
#  (957, 0),
#  (958, 0),
#  (959, 0),
#  (960, 0),
#  (961, 0),
#  (962, 0),
#  (963, 2),
#  (964, 0),
#  (965, 0),
#  (966, 0),
#  (967, 0),
#  (968, 2),
#  (969, 1),
#  (970, 1),
#  (971, 0),
#  (972, 0),
#  (973, 1),
#  (974, 0),
#  (975, 0),
#  (976, 0),
#  (977, 0),
#  (978, 0),
#  (979, 1),
#  (980, 0),
#  (981, 0),
#  (982, 0),
#  (983, 0),
#  (984, 0),
#  (985, 0),
#  (986, 0),
#  (987, 0),
#  (988, 0),
#  (989, 4),
#  (990, 2),
#  (991, 2),
#  (992, 2),
#  (993, 1),
#  (994, 0),
#  (995, 2),
#  (996, 1),
#  (997, 2),
#  (998, 2),
#  (999, 3),
#  (1000, 6),
#  ...]

# %% [markdown]
# * The range of tracks in the store is not reflective of their sales popularity.

# %% [markdown]
# # Effect of media type on popularity of tracks bought

# %%
# %%sql
#
# CREATE VIEW invoice_track_protection AS
#     WITH media_type_protection AS (
#                                    SELECT
#                                        media_type_id,
#                                        CASE
#                                            WHEN name LIKE '%protected%' THEN 'protected'
#                                            ELSE 'non-protected'
#                                        END
#                                        AS protection_offered
#                                    FROM media_type
#                                   ),
#          track_media_type AS (
#                               SELECT
#                                   track_id,
#                                   media_type_id
#                               FROM track
#                              ),
#          track_protection AS (
#                               SELECT
#                                   tmt.track_id,
#                                   mtp.protection_offered
#                               FROM track_media_type AS tmt
#                               INNER JOIN media_type_protection AS mtp ON tmt.media_type_id = mtp.media_type_id
#                              ),
#          invoice_track_quantity AS (
#                                     SELECT
#                                         track_id,
#                                         quantity
#                                     FROM invoice_line
#                                    )
#     SELECT
#         itq.track_id,
#         itq.quantity,
#         tp.protection_offered
#     FROM invoice_track_quantity AS itq
#     LEFT JOIN track_protection AS tp ON itq.track_id = tp.track_id;
# Out:
#  * sqlite:///chinook.db
# Done.
# []

# %% [markdown]
# ## Overview

# %%
# %%sql
#
# SELECT
#     protection_offered,
#     SUM(quantity) AS total_track_sales
# FROM invoice_track_protection
# GROUP BY protection_offered;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('non-protected', 4315), ('protected', 442)]

# %% [markdown]
# * tracks having protections on them are sold much lesser (approx. 1/10th of non-protected tracks) than their unprotected tracks.

# %% [markdown]
# ## media types of popular tracks (according to sales info)

# %%
# %%sql
#
# SELECT
#     track_id,
#     SUM(quantity) AS track_sales_volume,
#     protection_offered
# FROM invoice_track_protection
# GROUP BY track_id
# ORDER BY track_sales_volume DESC;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3336, 31, 'non-protected'),
#  (1489, 14, 'non-protected'),
#  (1495, 14, 'non-protected'),
#  (6, 13, 'non-protected'),
#  (1487, 13, 'non-protected'),
#  (1490, 13, 'non-protected'),
#  (1483, 12, 'non-protected'),
#  (2558, 12, 'non-protected'),
#  (1129, 11, 'non-protected'),
#  (1479, 11, 'non-protected'),
#  (1485, 11, 'non-protected'),
#  (1488, 11, 'non-protected'),
#  (1491, 11, 'non-protected'),
#  (1493, 11, 'non-protected'),
#  (2563, 11, 'non-protected'),
#  (13, 10, 'non-protected'),
#  (1122, 10, 'non-protected'),
#  (1126, 10, 'non-protected'),
#  (1466, 10, 'non-protected'),
#  (1482, 10, 'non-protected'),
#  (1484, 10, 'non-protected'),
#  (1492, 10, 'non-protected'),
#  (2234, 10, 'non-protected'),
#  (2235, 10, 'non-protected'),
#  (2561, 10, 'non-protected'),
#  (2640, 10, 'non-protected'),
#  (2663, 10, 'non-protected'),
#  (3478, 10, 'protected'),
#  (9, 9, 'non-protected'),
#  (46, 9, 'non-protected'),
#  (151, 9, 'non-protected'),
#  (1121, 9, 'non-protected'),
#  (1132, 9, 'non-protected'),
#  (1470, 9, 'non-protected'),
#  (1480, 9, 'non-protected'),
#  (1481, 9, 'non-protected'),
#  (1486, 9, 'non-protected'),
#  (1494, 9, 'non-protected'),
#  (1988, 9, 'non-protected'),
#  (2231, 9, 'non-protected'),
#  (2554, 9, 'non-protected'),
#  (2560, 9, 'non-protected'),
#  (2564, 9, 'non-protected'),
#  (2600, 9, 'non-protected'),
#  (2639, 9, 'non-protected'),
#  (2662, 9, 'non-protected'),
#  (3293, 9, 'protected'),
#  (1, 8, 'non-protected'),
#  (16, 8, 'non-protected'),
#  (32, 8, 'non-protected'),
#  (58, 8, 'non-protected'),
#  (153, 8, 'non-protected'),
#  (1130, 8, 'non-protected'),
#  (1139, 8, 'non-protected'),
#  (1473, 8, 'non-protected'),
#  (1475, 8, 'non-protected'),
#  (1951, 8, 'non-protected'),
#  (1994, 8, 'non-protected'),
#  (2236, 8, 'non-protected'),
#  (2275, 8, 'non-protected'),
#  (2291, 8, 'non-protected'),
#  (2556, 8, 'non-protected'),
#  (2559, 8, 'non-protected'),
#  (2644, 8, 'non-protected'),
#  (2645, 8, 'non-protected'),
#  (2646, 8, 'non-protected'),
#  (2647, 8, 'non-protected'),
#  (2649, 8, 'non-protected'),
#  (2651, 8, 'non-protected'),
#  (2736, 8, 'non-protected'),
#  (3289, 8, 'protected'),
#  (3291, 8, 'protected'),
#  (3424, 8, 'protected'),
#  (3439, 8, 'protected'),
#  (3465, 8, 'protected'),
#  (3495, 8, 'protected'),
#  (12, 7, 'non-protected'),
#  (18, 7, 'non-protected'),
#  (20, 7, 'non-protected'),
#  (21, 7, 'non-protected'),
#  (33, 7, 'non-protected'),
#  (36, 7, 'non-protected'),
#  (39, 7, 'non-protected'),
#  (61, 7, 'non-protected'),
#  (80, 7, 'non-protected'),
#  (154, 7, 'non-protected'),
#  (158, 7, 'non-protected'),
#  (481, 7, 'non-protected'),
#  (1123, 7, 'non-protected'),
#  (1125, 7, 'non-protected'),
#  (1127, 7, 'non-protected'),
#  (1128, 7, 'non-protected'),
#  (1143, 7, 'non-protected'),
#  (1469, 7, 'non-protected'),
#  (1471, 7, 'non-protected'),
#  (1472, 7, 'non-protected'),
#  (1477, 7, 'non-protected'),
#  (1995, 7, 'non-protected'),
#  (1997, 7, 'non-protected'),
#  (2229, 7, 'non-protected'),
#  (2232, 7, 'non-protected'),
#  (2237, 7, 'non-protected'),
#  (2278, 7, 'non-protected'),
#  (2292, 7, 'non-protected'),
#  (2548, 7, 'non-protected'),
#  (2555, 7, 'non-protected'),
#  (2641, 7, 'non-protected'),
#  (2648, 7, 'non-protected'),
#  (2658, 7, 'non-protected'),
#  (2693, 7, 'non-protected'),
#  (8, 6, 'non-protected'),
#  (10, 6, 'non-protected'),
#  (14, 6, 'non-protected'),
#  (19, 6, 'non-protected'),
#  (22, 6, 'non-protected'),
#  (23, 6, 'non-protected'),
#  (24, 6, 'non-protected'),
#  (26, 6, 'non-protected'),
#  (27, 6, 'non-protected'),
#  (30, 6, 'non-protected'),
#  (35, 6, 'non-protected'),
#  (38, 6, 'non-protected'),
#  (40, 6, 'non-protected'),
#  (42, 6, 'non-protected'),
#  (43, 6, 'non-protected'),
#  (44, 6, 'non-protected'),
#  (49, 6, 'non-protected'),
#  (54, 6, 'non-protected'),
#  (60, 6, 'non-protected'),
#  (94, 6, 'non-protected'),
#  (421, 6, 'non-protected'),
#  (1000, 6, 'non-protected'),
#  (1004, 6, 'non-protected'),
#  (1131, 6, 'non-protected'),
#  (1138, 6, 'non-protected'),
#  (1144, 6, 'non-protected'),
#  (1167, 6, 'protected'),
#  (1419, 6, 'non-protected'),
#  (1476, 6, 'non-protected'),
#  (1478, 6, 'non-protected'),
#  (1787, 6, 'non-protected'),
#  (2004, 6, 'non-protected'),
#  (2008, 6, 'non-protected'),
#  (2013, 6, 'non-protected'),
#  (2214, 6, 'non-protected'),
#  (2254, 6, 'non-protected'),
#  (2263, 6, 'non-protected'),
#  (2265, 6, 'non-protected'),
#  (2268, 6, 'non-protected'),
#  (2269, 6, 'non-protected'),
#  (2270, 6, 'non-protected'),
#  (2272, 6, 'non-protected'),
#  (2277, 6, 'non-protected'),
#  (2280, 6, 'non-protected'),
#  (2281, 6, 'non-protected'),
#  (2287, 6, 'non-protected'),
#  (2288, 6, 'non-protected'),
#  (2383, 6, 'non-protected'),
#  (2395, 6, 'non-protected'),
#  (2401, 6, 'non-protected'),
#  (2509, 6, 'non-protected'),
#  (2553, 6, 'non-protected'),
#  (2562, 6, 'non-protected'),
#  (2596, 6, 'non-protected'),
#  (2597, 6, 'non-protected'),
#  (2642, 6, 'non-protected'),
#  (2655, 6, 'non-protected'),
#  (2669, 6, 'non-protected'),
#  (2675, 6, 'non-protected'),
#  (2731, 6, 'non-protected'),
#  (2746, 6, 'non-protected'),
#  (3288, 6, 'protected'),
#  (3290, 6, 'protected'),
#  (3292, 6, 'protected'),
#  (3297, 6, 'protected'),
#  (3299, 6, 'protected'),
#  (3378, 6, 'protected'),
#  (3460, 6, 'protected'),
#  (3461, 6, 'protected'),
#  (3473, 6, 'protected'),
#  (11, 5, 'non-protected'),
#  (17, 5, 'non-protected'),
#  (29, 5, 'non-protected'),
#  (45, 5, 'non-protected'),
#  (47, 5, 'non-protected'),
#  (48, 5, 'non-protected'),
#  (51, 5, 'non-protected'),
#  (62, 5, 'non-protected'),
#  (77, 5, 'non-protected'),
#  (81, 5, 'non-protected'),
#  (82, 5, 'non-protected'),
#  (83, 5, 'non-protected'),
#  (93, 5, 'non-protected'),
#  (152, 5, 'non-protected'),
#  (426, 5, 'non-protected'),
#  (479, 5, 'non-protected'),
#  (529, 5, 'non-protected'),
#  (697, 5, 'non-protected'),
#  (894, 5, 'non-protected'),
#  (897, 5, 'non-protected'),
#  (1005, 5, 'non-protected'),
#  (1008, 5, 'non-protected'),
#  (1030, 5, 'non-protected'),
#  (1042, 5, 'non-protected'),
#  (1053, 5, 'non-protected'),
#  (1124, 5, 'non-protected'),
#  (1145, 5, 'non-protected'),
#  (1162, 5, 'protected'),
#  (1166, 5, 'protected'),
#  (1184, 5, 'non-protected'),
#  (1425, 5, 'non-protected'),
#  (1445, 5, 'non-protected'),
#  (1457, 5, 'non-protected'),
#  (1467, 5, 'non-protected'),
#  (1468, 5, 'non-protected'),
#  (1474, 5, 'non-protected'),
#  (1778, 5, 'non-protected'),
#  (1905, 5, 'non-protected'),
#  (1907, 5, 'non-protected'),
#  (1914, 5, 'non-protected'),
#  (1947, 5, 'non-protected'),
#  (1990, 5, 'non-protected'),
#  (1992, 5, 'non-protected'),
#  (1996, 5, 'non-protected'),
#  (2005, 5, 'non-protected'),
#  (2006, 5, 'non-protected'),
#  (2007, 5, 'non-protected'),
#  (2012, 5, 'non-protected'),
#  (2207, 5, 'non-protected'),
#  (2230, 5, 'non-protected'),
#  (2233, 5, 'non-protected'),
#  (2255, 5, 'non-protected'),
#  (2261, 5, 'non-protected'),
#  (2271, 5, 'non-protected'),
#  (2273, 5, 'non-protected'),
#  (2274, 5, 'non-protected'),
#  (2276, 5, 'non-protected'),
#  (2279, 5, 'non-protected'),
#  (2285, 5, 'non-protected'),
#  (2289, 5, 'non-protected'),
#  (2293, 5, 'non-protected'),
#  (2295, 5, 'non-protected'),
#  (2377, 5, 'non-protected'),
#  (2381, 5, 'non-protected'),
#  (2382, 5, 'non-protected'),
#  (2402, 5, 'non-protected'),
#  (2413, 5, 'non-protected'),
#  (2419, 5, 'non-protected'),
#  (2515, 5, 'non-protected'),
#  (2516, 5, 'non-protected'),
#  (2519, 5, 'non-protected'),
#  (2549, 5, 'non-protected'),
#  (2603, 5, 'non-protected'),
#  (2604, 5, 'non-protected'),
#  (2607, 5, 'non-protected'),
#  (2650, 5, 'non-protected'),
#  (2652, 5, 'non-protected'),
#  (2653, 5, 'non-protected'),
#  (2654, 5, 'non-protected'),
#  (2656, 5, 'non-protected'),
#  (2657, 5, 'non-protected'),
#  (2671, 5, 'non-protected'),
#  (2690, 5, 'non-protected'),
#  (2740, 5, 'non-protected'),
#  (2742, 5, 'non-protected'),
#  (2749, 5, 'non-protected'),
#  (3081, 5, 'non-protected'),
#  (3294, 5, 'protected'),
#  (3295, 5, 'protected'),
#  (3296, 5, 'protected'),
#  (3376, 5, 'protected'),
#  (3377, 5, 'protected'),
#  (3409, 5, 'protected'),
#  (3458, 5, 'protected'),
#  (3468, 5, 'protected'),
#  (3469, 5, 'protected'),
#  (3470, 5, 'protected'),
#  (3474, 5, 'protected'),
#  (4, 4, 'protected'),
#  (7, 4, 'non-protected'),
#  (15, 4, 'non-protected'),
#  (28, 4, 'non-protected'),
#  (31, 4, 'non-protected'),
#  (34, 4, 'non-protected'),
#  (41, 4, 'non-protected'),
#  (50, 4, 'non-protected'),
#  (52, 4, 'non-protected'),
#  (53, 4, 'non-protected'),
#  (55, 4, 'non-protected'),
#  (57, 4, 'non-protected'),
#  (79, 4, 'non-protected'),
#  (85, 4, 'non-protected'),
#  (150, 4, 'non-protected'),
#  (155, 4, 'non-protected'),
#  (157, 4, 'non-protected'),
#  (419, 4, 'non-protected'),
#  (422, 4, 'non-protected'),
#  (427, 4, 'non-protected'),
#  (444, 4, 'non-protected'),
#  (449, 4, 'non-protected'),
#  (711, 4, 'non-protected'),
#  (836, 4, 'non-protected'),
#  (898, 4, 'non-protected'),
#  (900, 4, 'non-protected'),
#  (901, 4, 'non-protected'),
#  (904, 4, 'non-protected'),
#  (905, 4, 'non-protected'),
#  (908, 4, 'non-protected'),
#  (989, 4, 'non-protected'),
#  (1002, 4, 'non-protected'),
#  (1006, 4, 'non-protected'),
#  (1023, 4, 'non-protected'),
#  (1025, 4, 'non-protected'),
#  (1026, 4, 'non-protected'),
#  (1029, 4, 'non-protected'),
#  (1033, 4, 'non-protected'),
#  (1039, 4, 'non-protected'),
#  (1040, 4, 'non-protected'),
#  (1041, 4, 'non-protected'),
#  (1046, 4, 'non-protected'),
#  (1050, 4, 'non-protected'),
#  (1051, 4, 'non-protected'),
#  (1134, 4, 'non-protected'),
#  (1135, 4, 'non-protected'),
#  (1136, 4, 'non-protected'),
#  (1140, 4, 'non-protected'),
#  (1149, 4, 'protected'),
#  (1160, 4, 'protected'),
#  (1163, 4, 'protected'),
#  (1168, 4, 'protected'),
#  (1173, 4, 'protected'),
#  (1175, 4, 'non-protected'),
#  (1178, 4, 'non-protected'),
#  (1180, 4, 'non-protected'),
#  (1422, 4, 'non-protected'),
#  (1424, 4, 'non-protected'),
#  (1428, 4, 'non-protected'),
#  (1435, 4, 'non-protected'),
#  (1439, 4, 'non-protected'),
#  (1462, 4, 'non-protected'),
#  (1463, 4, 'non-protected'),
#  (1641, 4, 'non-protected'),
#  (1757, 4, 'non-protected'),
#  (1758, 4, 'non-protected'),
#  (1763, 4, 'non-protected'),
#  (1774, 4, 'non-protected'),
#  (1784, 4, 'non-protected'),
#  (1788, 4, 'non-protected'),
#  (1854, 4, 'non-protected'),
#  (1903, 4, 'non-protected'),
#  (1904, 4, 'non-protected'),
#  (1912, 4, 'non-protected'),
#  (1913, 4, 'non-protected'),
#  (1915, 4, 'non-protected'),
#  (1942, 4, 'non-protected'),
#  (1948, 4, 'non-protected'),
#  (1950, 4, 'non-protected'),
#  (1955, 4, 'non-protected'),
#  (1989, 4, 'non-protected'),
#  (2001, 4, 'non-protected'),
#  (2002, 4, 'non-protected'),
#  (2187, 4, 'non-protected'),
#  (2256, 4, 'non-protected'),
#  (2257, 4, 'non-protected'),
#  (2258, 4, 'non-protected'),
#  (2260, 4, 'non-protected'),
#  (2262, 4, 'non-protected'),
#  (2264, 4, 'non-protected'),
#  (2266, 4, 'non-protected'),
#  (2286, 4, 'non-protected'),
#  (2290, 4, 'non-protected'),
#  (2294, 4, 'non-protected'),
#  (2303, 4, 'non-protected'),
#  (2307, 4, 'non-protected'),
#  (2368, 4, 'non-protected'),
#  (2385, 4, 'non-protected'),
#  (2391, 4, 'non-protected'),
#  (2396, 4, 'non-protected'),
#  (2400, 4, 'non-protected'),
#  (2414, 4, 'non-protected'),
#  (2416, 4, 'non-protected'),
#  (2507, 4, 'non-protected'),
#  (2514, 4, 'non-protected'),
#  (2517, 4, 'non-protected'),
#  (2544, 4, 'non-protected'),
#  (2557, 4, 'non-protected'),
#  (2592, 4, 'non-protected'),
#  (2594, 4, 'non-protected'),
#  (2599, 4, 'non-protected'),
#  (2601, 4, 'non-protected'),
#  (2643, 4, 'non-protected'),
#  (2660, 4, 'non-protected'),
#  (2664, 4, 'non-protected'),
#  (2668, 4, 'non-protected'),
#  (2670, 4, 'non-protected'),
#  (2673, 4, 'non-protected'),
#  (2674, 4, 'non-protected'),
#  (2687, 4, 'non-protected'),
#  (2698, 4, 'non-protected'),
#  (2735, 4, 'non-protected'),
#  (2738, 4, 'non-protected'),
#  (2747, 4, 'non-protected'),
#  (2748, 4, 'non-protected'),
#  (3006, 4, 'non-protected'),
#  (3060, 4, 'non-protected'),
#  (3078, 4, 'non-protected'),
#  (3104, 4, 'non-protected'),
#  (3298, 4, 'protected'),
#  (3379, 4, 'protected'),
#  (3385, 4, 'protected'),
#  (3387, 4, 'protected'),
#  (3388, 4, 'protected'),
#  (3456, 4, 'protected'),
#  (3457, 4, 'protected'),
#  (3459, 4, 'protected'),
#  (3463, 4, 'protected'),
#  (3467, 4, 'protected'),
#  (3475, 4, 'protected'),
#  (3476, 4, 'protected'),
#  (2, 3, 'protected'),
#  (37, 3, 'non-protected'),
#  (56, 3, 'non-protected'),
#  (59, 3, 'non-protected'),
#  (66, 3, 'non-protected'),
#  (78, 3, 'non-protected'),
#  (84, 3, 'non-protected'),
#  (102, 3, 'non-protected'),
#  (160, 3, 'non-protected'),
#  (162, 3, 'non-protected'),
#  (163, 3, 'non-protected'),
#  (164, 3, 'non-protected'),
#  (165, 3, 'non-protected'),
#  (195, 3, 'non-protected'),
#  (198, 3, 'non-protected'),
#  (201, 3, 'non-protected'),
#  (204, 3, 'non-protected'),
#  (207, 3, 'non-protected'),
#  (423, 3, 'non-protected'),
#  (428, 3, 'non-protected'),
#  (433, 3, 'non-protected'),
#  (459, 3, 'non-protected'),
#  (469, 3, 'non-protected'),
#  (470, 3, 'non-protected'),
#  (475, 3, 'non-protected'),
#  (482, 3, 'non-protected'),
#  (486, 3, 'non-protected'),
#  (548, 3, 'non-protected'),
#  (572, 3, 'non-protected'),
#  (610, 3, 'non-protected'),
#  (615, 3, 'non-protected'),
#  (699, 3, 'non-protected'),
#  (778, 3, 'non-protected'),
#  (834, 3, 'non-protected'),
#  (839, 3, 'non-protected'),
#  (892, 3, 'non-protected'),
#  (895, 3, 'non-protected'),
#  (896, 3, 'non-protected'),
#  (899, 3, 'non-protected'),
#  (902, 3, 'non-protected'),
#  (906, 3, 'non-protected'),
#  (917, 3, 'non-protected'),
#  (920, 3, 'non-protected'),
#  (937, 3, 'non-protected'),
#  (999, 3, 'non-protected'),
#  (1001, 3, 'non-protected'),
#  (1003, 3, 'non-protected'),
#  (1007, 3, 'non-protected'),
#  (1009, 3, 'non-protected'),
#  (1015, 3, 'non-protected'),
#  (1017, 3, 'non-protected'),
#  (1019, 3, 'non-protected'),
#  (1021, 3, 'non-protected'),
#  (1027, 3, 'non-protected'),
#  (1036, 3, 'non-protected'),
#  (1037, 3, 'non-protected'),
#  (1043, 3, 'non-protected'),
#  (1044, 3, 'non-protected'),
#  (1048, 3, 'non-protected'),
#  (1052, 3, 'non-protected'),
#  (1055, 3, 'non-protected'),
#  (1133, 3, 'non-protected'),
#  (1141, 3, 'non-protected'),
#  (1148, 3, 'protected'),
#  (1150, 3, 'protected'),
#  (1151, 3, 'protected'),
#  (1153, 3, 'protected'),
#  (1155, 3, 'protected'),
#  (1156, 3, 'protected'),
#  (1157, 3, 'protected'),
#  (1164, 3, 'protected'),
#  (1170, 3, 'protected'),
#  (1176, 3, 'non-protected'),
#  (1181, 3, 'non-protected'),
#  (1185, 3, 'non-protected'),
#  (1187, 3, 'non-protected'),
#  (1292, 3, 'non-protected'),
#  (1387, 3, 'non-protected'),
#  (1415, 3, 'non-protected'),
#  (1442, 3, 'non-protected'),
#  (1456, 3, 'non-protected'),
#  (1458, 3, 'non-protected'),
#  (1459, 3, 'non-protected'),
#  (1547, 3, 'non-protected'),
#  (1553, 3, 'non-protected'),
#  (1554, 3, 'non-protected'),
#  (1561, 3, 'non-protected'),
#  (1568, 3, 'non-protected'),
#  (1570, 3, 'non-protected'),
#  (1602, 3, 'non-protected'),
#  (1617, 3, 'non-protected'),
#  (1669, 3, 'non-protected'),
#  (1756, 3, 'non-protected'),
#  (1759, 3, 'non-protected'),
#  (1761, 3, 'non-protected'),
#  (1764, 3, 'non-protected'),
#  (1768, 3, 'non-protected'),
#  (1776, 3, 'non-protected'),
#  (1780, 3, 'non-protected'),
#  (1782, 3, 'non-protected'),
#  (1785, 3, 'non-protected'),
#  (1786, 3, 'non-protected'),
#  (1789, 3, 'non-protected'),
#  (1797, 3, 'non-protected'),
#  (1800, 3, 'non-protected'),
#  (1834, 3, 'non-protected'),
#  (1837, 3, 'non-protected'),
#  (1853, 3, 'non-protected'),
#  (1855, 3, 'non-protected'),
#  (1856, 3, 'non-protected'),
#  (1890, 3, 'non-protected'),
#  (1902, 3, 'non-protected'),
#  (1906, 3, 'non-protected'),
#  (1908, 3, 'non-protected'),
#  (1909, 3, 'non-protected'),
#  (1910, 3, 'non-protected'),
#  (1911, 3, 'non-protected'),
#  (1944, 3, 'non-protected'),
#  (1949, 3, 'non-protected'),
#  (1956, 3, 'non-protected'),
#  (1984, 3, 'non-protected'),
#  (1987, 3, 'non-protected'),
#  (1991, 3, 'non-protected'),
#  (1993, 3, 'non-protected'),
#  (1998, 3, 'non-protected'),
#  (1999, 3, 'non-protected'),
#  (2000, 3, 'non-protected'),
#  (2009, 3, 'non-protected'),
#  (2010, 3, 'non-protected'),
#  (2011, 3, 'non-protected'),
#  (2014, 3, 'non-protected'),
#  (2106, 3, 'non-protected'),
#  (2149, 3, 'non-protected'),
#  (2150, 3, 'non-protected'),
#  (2151, 3, 'non-protected'),
#  (2160, 3, 'non-protected'),
#  (2161, 3, 'non-protected'),
#  (2164, 3, 'non-protected'),
#  (2169, 3, 'non-protected'),
#  (2171, 3, 'non-protected'),
#  (2172, 3, 'non-protected'),
#  (2189, 3, 'non-protected'),
#  (2191, 3, 'non-protected'),
#  (2192, 3, 'non-protected'),
#  (2201, 3, 'non-protected'),
#  (2204, 3, 'non-protected'),
#  (2205, 3, 'non-protected'),
#  (2206, 3, 'non-protected'),
#  (2208, 3, 'non-protected'),
#  (2210, 3, 'non-protected'),
#  (2215, 3, 'non-protected'),
#  (2220, 3, 'non-protected'),
#  (2259, 3, 'non-protected'),
#  (2267, 3, 'non-protected'),
#  (2296, 3, 'non-protected'),
#  (2298, 3, 'non-protected'),
#  (2302, 3, 'non-protected'),
#  (2332, 3, 'non-protected'),
#  (2361, 3, 'non-protected'),
#  (2365, 3, 'non-protected'),
#  (2367, 3, 'non-protected'),
#  (2376, 3, 'non-protected'),
#  (2378, 3, 'non-protected'),
#  (2380, 3, 'non-protected'),
#  (2386, 3, 'non-protected'),
#  (2389, 3, 'non-protected'),
#  (2392, 3, 'non-protected'),
#  (2393, 3, 'non-protected'),
#  (2404, 3, 'non-protected'),
#  (2406, 3, 'non-protected'),
#  (2407, 3, 'non-protected'),
#  (2410, 3, 'non-protected'),
#  (2417, 3, 'non-protected'),
#  (2418, 3, 'non-protected'),
#  (2421, 3, 'non-protected'),
#  (2433, 3, 'non-protected'),
#  (2508, 3, 'non-protected'),
#  (2510, 3, 'non-protected'),
#  (2518, 3, 'non-protected'),
#  (2542, 3, 'non-protected'),
#  (2543, 3, 'non-protected'),
#  (2547, 3, 'non-protected'),
#  (2551, 3, 'non-protected'),
#  (2590, 3, 'non-protected'),
#  (2591, 3, 'non-protected'),
#  (2593, 3, 'non-protected'),
#  (2602, 3, 'non-protected'),
#  (2605, 3, 'non-protected'),
#  (2621, 3, 'non-protected'),
#  (2624, 3, 'non-protected'),
#  (2628, 3, 'non-protected'),
#  (2630, 3, 'non-protected'),
#  (2634, 3, 'non-protected'),
#  (2636, 3, 'non-protected'),
#  (2659, 3, 'non-protected'),
#  (2661, 3, 'non-protected'),
#  (2666, 3, 'non-protected'),
#  (2672, 3, 'non-protected'),
#  (2677, 3, 'non-protected'),
#  (2679, 3, 'non-protected'),
#  (2683, 3, 'non-protected'),
#  (2691, 3, 'non-protected'),
#  (2696, 3, 'non-protected'),
#  (2697, 3, 'non-protected'),
#  (2701, 3, 'non-protected'),
#  (2704, 3, 'non-protected'),
#  (2734, 3, 'non-protected'),
#  (2737, 3, 'non-protected'),
#  (2741, 3, 'non-protected'),
#  (2743, 3, 'non-protected'),
#  (2744, 3, 'non-protected'),
#  (3044, 3, 'non-protected'),
#  (3050, 3, 'non-protected'),
#  (3051, 3, 'non-protected'),
#  (3059, 3, 'non-protected'),
#  (3067, 3, 'non-protected'),
#  (3069, 3, 'non-protected'),
#  (3076, 3, 'non-protected'),
#  (3087, 3, 'non-protected'),
#  (3089, 3, 'non-protected'),
#  (3094, 3, 'non-protected'),
#  (3100, 3, 'non-protected'),
#  (3102, 3, 'non-protected'),
#  (3109, 3, 'non-protected'),
#  (3115, 3, 'non-protected'),
#  (3142, 3, 'non-protected'),
#  (3307, 3, 'non-protected'),
#  (3314, 3, 'non-protected'),
#  (3353, 3, 'non-protected'),
#  (3355, 3, 'non-protected'),
#  (3356, 3, 'non-protected'),
#  (3357, 3, 'non-protected'),
#  (3358, 3, 'non-protected'),
#  (3359, 3, 'non-protected'),
#  (3375, 3, 'protected'),
#  (3380, 3, 'protected'),
#  (3382, 3, 'protected'),
#  (3386, 3, 'protected'),
#  (3452, 3, 'non-protected'),
#  (3455, 3, 'protected'),
#  (3466, 3, 'protected'),
#  (3471, 3, 'protected'),
#  (3472, 3, 'protected'),
#  (3477, 3, 'protected'),
#  (25, 2, 'non-protected'),
#  (73, 2, 'non-protected'),
#  (76, 2, 'non-protected'),
#  (86, 2, 'non-protected'),
#  (88, 2, 'non-protected'),
#  (89, 2, 'non-protected'),
#  (91, 2, 'non-protected'),
#  (92, 2, 'non-protected'),
#  (95, 2, 'non-protected'),
#  (97, 2, 'non-protected'),
#  (110, 2, 'non-protected'),
#  (130, 2, 'non-protected'),
#  (134, 2, 'non-protected'),
#  (139, 2, 'non-protected'),
#  (146, 2, 'non-protected'),
#  (147, 2, 'non-protected'),
#  (149, 2, 'non-protected'),
#  (161, 2, 'non-protected'),
#  (172, 2, 'non-protected'),
#  (196, 2, 'non-protected'),
#  (197, 2, 'non-protected'),
#  (199, 2, 'non-protected'),
#  (202, 2, 'non-protected'),
#  (226, 2, 'non-protected'),
#  (337, 2, 'non-protected'),
#  (411, 2, 'non-protected'),
#  (415, 2, 'non-protected'),
#  (424, 2, 'non-protected'),
#  (425, 2, 'non-protected'),
#  (430, 2, 'non-protected'),
#  (431, 2, 'non-protected'),
#  (432, 2, 'non-protected'),
#  (434, 2, 'non-protected'),
#  (435, 2, 'non-protected'),
#  (436, 2, 'non-protected'),
#  (437, 2, 'non-protected'),
#  (438, 2, 'non-protected'),
#  (439, 2, 'non-protected'),
#  (441, 2, 'non-protected'),
#  (442, 2, 'non-protected'),
#  (445, 2, 'non-protected'),
#  (446, 2, 'non-protected'),
#  (452, 2, 'non-protected'),
#  (453, 2, 'non-protected'),
#  (454, 2, 'non-protected'),
#  (468, 2, 'non-protected'),
#  (472, 2, 'non-protected'),
#  (474, 2, 'non-protected'),
#  (476, 2, 'non-protected'),
#  (477, 2, 'non-protected'),
#  (485, 2, 'non-protected'),
#  (488, 2, 'non-protected'),
#  (530, 2, 'non-protected'),
#  (531, 2, 'non-protected'),
#  (532, 2, 'non-protected'),
#  (535, 2, 'non-protected'),
#  (536, 2, 'non-protected'),
#  (539, 2, 'non-protected'),
#  (540, 2, 'non-protected'),
#  (541, 2, 'non-protected'),
#  (542, 2, 'non-protected'),
#  (571, 2, 'non-protected'),
#  (580, 2, 'non-protected'),
#  (592, 2, 'non-protected'),
#  (597, 2, 'non-protected'),
#  (605, 2, 'non-protected'),
#  (608, 2, 'non-protected'),
#  (681, 2, 'non-protected'),
#  (690, 2, 'non-protected'),
#  (692, 2, 'non-protected'),
#  (695, 2, 'non-protected'),
#  (696, 2, 'non-protected'),
#  (698, 2, 'non-protected'),
#  (700, 2, 'non-protected'),
#  (701, 2, 'non-protected'),
#  (705, 2, 'non-protected'),
#  (706, 2, 'non-protected'),
#  (707, 2, 'non-protected'),
#  (709, 2, 'non-protected'),
#  (712, 2, 'non-protected'),
#  (751, 2, 'non-protected'),
#  (773, 2, 'non-protected'),
#  (781, 2, 'non-protected'),
#  (802, 2, 'non-protected'),
#  (807, 2, 'non-protected'),
#  (810, 2, 'non-protected'),
#  (814, 2, 'non-protected'),
#  (819, 2, 'non-protected'),
#  (822, 2, 'non-protected'),
#  (826, 2, 'non-protected'),
#  (829, 2, 'non-protected'),
#  (831, 2, 'non-protected'),
#  (832, 2, 'non-protected'),
#  (833, 2, 'non-protected'),
#  (837, 2, 'non-protected'),
#  (841, 2, 'non-protected'),
#  (891, 2, 'non-protected'),
#  (893, 2, 'non-protected'),
#  (903, 2, 'non-protected'),
#  (907, 2, 'non-protected'),
#  (913, 2, 'non-protected'),
#  (915, 2, 'non-protected'),
#  (918, 2, 'non-protected'),
#  (921, 2, 'non-protected'),
#  (922, 2, 'non-protected'),
#  (944, 2, 'non-protected'),
#  (963, 2, 'non-protected'),
#  (968, 2, 'non-protected'),
#  (990, 2, 'non-protected'),
#  (991, 2, 'non-protected'),
#  (992, 2, 'non-protected'),
#  (995, 2, 'non-protected'),
#  (997, 2, 'non-protected'),
#  (998, 2, 'non-protected'),
#  (1010, 2, 'non-protected'),
#  (1011, 2, 'non-protected'),
#  (1012, 2, 'non-protected'),
#  (1013, 2, 'non-protected'),
#  (1014, 2, 'non-protected'),
#  (1018, 2, 'non-protected'),
#  (1028, 2, 'non-protected'),
#  (1031, 2, 'non-protected'),
#  (1032, 2, 'non-protected'),
#  (1034, 2, 'non-protected'),
#  (1035, 2, 'non-protected'),
#  (1038, 2, 'non-protected'),
#  (1045, 2, 'non-protected'),
#  (1047, 2, 'non-protected'),
#  (1054, 2, 'non-protected'),
#  (1056, 2, 'non-protected'),
#  (1102, 2, 'non-protected'),
#  (1108, 2, 'non-protected'),
#  (1109, 2, 'non-protected'),
#  (1137, 2, 'non-protected'),
#  (1142, 2, 'non-protected'),
#  (1146, 2, 'protected'),
#  (1147, 2, 'protected'),
#  (1152, 2, 'protected'),
#  (1154, 2, 'protected'),
#  (1158, 2, 'protected'),
#  (1159, 2, 'protected'),
#  (1161, 2, 'protected'),
#  (1165, 2, 'protected'),
#  (1169, 2, 'protected'),
#  (1172, 2, 'protected'),
#  (1174, 2, 'non-protected'),
#  (1177, 2, 'non-protected'),
#  (1179, 2, 'non-protected'),
#  (1182, 2, 'non-protected'),
#  (1183, 2, 'non-protected'),
#  (1188, 2, 'non-protected'),
#  (1195, 2, 'non-protected'),
#  (1250, 2, 'non-protected'),
#  (1268, 2, 'non-protected'),
#  (1332, 2, 'non-protected'),
#  (1351, 2, 'non-protected'),
#  (1372, 2, 'non-protected'),
#  (1414, 2, 'non-protected'),
#  (1416, 2, 'non-protected'),
#  (1418, 2, 'non-protected'),
#  (1420, 2, 'non-protected'),
#  (1421, 2, 'non-protected'),
#  (1426, 2, 'non-protected'),
#  (1427, 2, 'non-protected'),
#  (1430, 2, 'non-protected'),
#  (1431, 2, 'non-protected'),
#  (1434, 2, 'non-protected'),
#  (1436, 2, 'non-protected'),
#  (1437, 2, 'non-protected'),
#  (1440, 2, 'non-protected'),
#  (1441, 2, 'non-protected'),
#  (1455, 2, 'non-protected'),
#  (1460, 2, 'non-protected'),
#  (1461, 2, 'non-protected'),
#  (1464, 2, 'non-protected'),
#  (1496, 2, 'protected'),
#  (1501, 2, 'protected'),
#  (1502, 2, 'protected'),
#  (1512, 2, 'non-protected'),
#  (1520, 2, 'non-protected'),
#  (1521, 2, 'non-protected'),
#  (1522, 2, 'non-protected'),
#  (1523, 2, 'non-protected'),
#  (1528, 2, 'non-protected'),
#  (1531, 2, 'non-protected'),
#  (1549, 2, 'non-protected'),
#  (1550, 2, 'non-protected'),
#  (1551, 2, 'non-protected'),
#  (1552, 2, 'non-protected'),
#  (1556, 2, 'non-protected'),
#  (1559, 2, 'non-protected'),
#  (1560, 2, 'non-protected'),
#  (1562, 2, 'non-protected'),
#  (1563, 2, 'non-protected'),
#  (1565, 2, 'non-protected'),
#  (1566, 2, 'non-protected'),
#  (1567, 2, 'non-protected'),
#  (1569, 2, 'non-protected'),
#  (1573, 2, 'non-protected'),
#  (1580, 2, 'non-protected'),
#  (1586, 2, 'non-protected'),
#  (1591, 2, 'non-protected'),
#  (1610, 2, 'non-protected'),
#  (1623, 2, 'non-protected'),
#  (1626, 2, 'non-protected'),
#  (1656, 2, 'non-protected'),
#  (1657, 2, 'non-protected'),
#  (1696, 2, 'non-protected'),
#  (1703, 2, 'non-protected'),
#  (1745, 2, 'non-protected'),
#  (1746, 2, 'non-protected'),
#  (1747, 2, 'non-protected'),
#  (1748, 2, 'non-protected'),
#  (1750, 2, 'non-protected'),
#  (1752, 2, 'non-protected'),
#  (1754, 2, 'non-protected'),
#  (1755, 2, 'non-protected'),
#  (1760, 2, 'non-protected'),
#  (1762, 2, 'non-protected'),
#  (1765, 2, 'non-protected'),
#  (1766, 2, 'non-protected'),
#  (1767, 2, 'non-protected'),
#  (1769, 2, 'non-protected'),
#  (1770, 2, 'non-protected'),
#  (1771, 2, 'non-protected'),
#  (1772, 2, 'non-protected'),
#  (1775, 2, 'non-protected'),
#  (1783, 2, 'non-protected'),
#  (1790, 2, 'non-protected'),
#  (1794, 2, 'non-protected'),
#  (1796, 2, 'non-protected'),
#  (1798, 2, 'non-protected'),
#  (1799, 2, 'non-protected'),
#  (1802, 2, 'non-protected'),
#  (1810, 2, 'non-protected'),
#  (1814, 2, 'non-protected'),
#  (1823, 2, 'non-protected'),
#  (1826, 2, 'non-protected'),
#  (1828, 2, 'non-protected'),
#  (1829, 2, 'non-protected'),
#  (1838, 2, 'non-protected'),
#  (1849, 2, 'non-protected'),
#  (1857, 2, 'non-protected'),
#  (1858, 2, 'non-protected'),
#  (1859, 2, 'non-protected'),
#  (1860, 2, 'non-protected'),
#  (1865, 2, 'non-protected'),
#  (1876, 2, 'non-protected'),
#  (1880, 2, 'non-protected'),
#  (1886, 2, 'non-protected'),
#  (1887, 2, 'non-protected'),
#  (1888, 2, 'non-protected'),
#  (1889, 2, 'non-protected'),
#  (1891, 2, 'non-protected'),
#  (1937, 2, 'non-protected'),
#  (1943, 2, 'non-protected'),
#  (1945, 2, 'non-protected'),
#  (1946, 2, 'non-protected'),
#  (1953, 2, 'non-protected'),
#  (1977, 2, 'non-protected'),
#  (1986, 2, 'non-protected'),
#  (2003, 2, 'non-protected'),
#  (2093, 2, 'protected'),
#  (2097, 2, 'protected'),
#  (2098, 2, 'protected'),
#  (2108, 2, 'non-protected'),
#  (2109, 2, 'non-protected'),
#  (2110, 2, 'non-protected'),
#  (2152, 2, 'non-protected'),
#  (2155, 2, 'non-protected'),
#  (2157, 2, 'non-protected'),
#  (2159, 2, 'non-protected'),
#  (2162, 2, 'non-protected'),
#  (2174, 2, 'non-protected'),
#  (2177, 2, 'non-protected'),
#  (2178, 2, 'non-protected'),
#  (2179, 2, 'non-protected'),
#  (2183, 2, 'non-protected'),
#  (2185, 2, 'non-protected'),
#  (2186, 2, 'non-protected'),
#  (2188, 2, 'non-protected'),
#  (2209, 2, 'non-protected'),
#  (2211, 2, 'non-protected'),
#  (2212, 2, 'non-protected'),
#  (2213, 2, 'non-protected'),
#  (2226, 2, 'non-protected'),
#  (2227, 2, 'non-protected'),
#  (2228, 2, 'non-protected'),
#  (2297, 2, 'non-protected'),
#  (2304, 2, 'non-protected'),
#  (2308, 2, 'non-protected'),
#  (2320, 2, 'non-protected'),
#  (2322, 2, 'non-protected'),
#  (2323, 2, 'non-protected'),
#  (2325, 2, 'non-protected'),
#  (2330, 2, 'non-protected'),
#  (2342, 2, 'non-protected'),
#  (2350, 2, 'non-protected'),
#  (2359, 2, 'non-protected'),
#  (2369, 2, 'non-protected'),
#  (2371, 2, 'non-protected'),
#  (2372, 2, 'non-protected'),
#  (2373, 2, 'non-protected'),
#  (2375, 2, 'non-protected'),
#  (2379, 2, 'non-protected'),
#  (2384, 2, 'non-protected'),
#  (2394, 2, 'non-protected'),
#  (2397, 2, 'non-protected'),
#  (2398, 2, 'non-protected'),
#  (2399, 2, 'non-protected'),
#  (2403, 2, 'non-protected'),
#  (2405, 2, 'non-protected'),
#  (2415, 2, 'non-protected'),
#  (2420, 2, 'non-protected'),
#  (2425, 2, 'non-protected'),
#  (2426, 2, 'non-protected'),
#  (2429, 2, 'non-protected'),
#  (2436, 2, 'non-protected'),
#  (2445, 2, 'non-protected'),
#  (2458, 2, 'non-protected'),
#  (2462, 2, 'non-protected'),
#  (2464, 2, 'non-protected'),
#  (2467, 2, 'non-protected'),
#  (2511, 2, 'non-protected'),
#  (2521, 2, 'non-protected'),
#  (2522, 2, 'non-protected'),
#  (2523, 2, 'non-protected'),
#  (2546, 2, 'non-protected'),
#  (2550, 2, 'non-protected'),
#  (2552, 2, 'non-protected'),
#  (2573, 2, 'non-protected'),
#  (2575, 2, 'non-protected'),
#  (2595, 2, 'non-protected'),
#  (2598, 2, 'non-protected'),
#  (2606, 2, 'non-protected'),
#  (2608, 2, 'non-protected'),
#  (2610, 2, 'non-protected'),
#  ...]

# %% [markdown]
# * As can be seen, amongst the top 20 tracks, there are no tracks that are protected. Hence, non-protected tracks are more popular amongst customers.
